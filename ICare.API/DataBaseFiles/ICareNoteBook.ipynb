-- %% [markdown]
-- # [dbo].[Cart]

-- %%
USE [ICare-Database2]
GO

-- %%
/****** Object:  Table [dbo].[Cart]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cart](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CreatedOn] [datetime2](7) NOT NULL,
	[PatientId] [int] NOT NULL,
	[DrugId] [int] NOT NULL,
 CONSTRAINT [PK_Cart] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Delivery]

-- %%
/****** Object:  Table [dbo].[Delivery]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Delivery](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CreatedOn] [datetime2](7) NOT NULL,
	[UserId] [int] NOT NULL,
 CONSTRAINT [PK_Delivery] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Drug]

-- %%
/****** Object:  Table [dbo].[Drug]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Drug](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CreatedOn] [datetime2](7) NOT NULL,
	[DrugCategoryId] [int] NOT NULL,
	[Name] [nvarchar](150) NOT NULL,
	[Price] [float] NOT NULL,
	[PicturePath] [nvarchar](250) NULL,
 CONSTRAINT [PK_Drug] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DrugCategory]

-- %%
/****** Object:  Table [dbo].[DrugCategory]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DrugCategory](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CreatedOn] [datetime2](7) NOT NULL,
	[Name] [nvarchar](100) NOT NULL,
	[PicturePath] [nvarchar](250) NULL,
 CONSTRAINT [PK_DrugCategory] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DrugDoseTime]

-- %%
/****** Object:  Table [dbo].[DrugDoseTime]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DrugDoseTime](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CreatedOn] [datetime2](7) NOT NULL,
	[PatientDrugId] [int] NOT NULL,
	[Time] [time](7) NOT NULL,
 CONSTRAINT [PK_DrugDoseTime] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Employee]

-- %%
/****** Object:  Table [dbo].[Employee]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Employee](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CreatedOn] [datetime2](7) NOT NULL,
	[HourSalary] [float] NOT NULL,
	[MonthlyWorkingHours] [int] NOT NULL,
	[PricePerHour] [float] NULL,
	[UserId] [int] NOT NULL,
 CONSTRAINT [PK_Employee] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[HealthReport]

-- %%
/****** Object:  Table [dbo].[HealthReport]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[HealthReport](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CreatedOn] [datetime2](7) NOT NULL,
	[PatientId] [int] NOT NULL,
	[TypeId] [int] NOT NULL,
	[Value] [float] NOT NULL,
 CONSTRAINT [PK_HealthReport] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[HealthReportTypes]

-- %%
/****** Object:  Table [dbo].[HealthReportTypes]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[HealthReportTypes](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CreatedOn] [datetime2](7) NOT NULL,
	[Type] [nvarchar](150) NOT NULL,
 CONSTRAINT [PK_HealthReportTypes] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Location]

-- %%
/****** Object:  Table [dbo].[Location]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Location](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CreatedOn] [datetime2](7) NOT NULL,
	[location] [nvarchar](max) NULL,
 CONSTRAINT [PK_Location] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Notification]

-- %%
/****** Object:  Table [dbo].[Notification]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Notification](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CreatedOn] [datetime2](7) NOT NULL,
	[Message] [nvarchar](1500) NOT NULL,
	[PatientId] [int] NOT NULL,
	[NotificationTypeId] [int] NOT NULL,
 CONSTRAINT [PK_Notification] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NotificationTypes]

-- %%
/****** Object:  Table [dbo].[NotificationTypes]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NotificationTypes](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CreatedOn] [datetime2](7) NOT NULL,
	[Type] [nvarchar](150) NOT NULL,
 CONSTRAINT [PK_NotificationTypes] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Order]

-- %%
/****** Object:  Table [dbo].[Order]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Order](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CreatedOn] [datetime2](7) NOT NULL,
	[TotalPrice] [float] NOT NULL,
	[StatusId] [int] NOT NULL,
	[DeliveryId] [int] NULL,
	[PatientId] [int] NOT NULL,
 CONSTRAINT [PK_Order] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[OrderDrugs]

-- %%
/****** Object:  Table [dbo].[OrderDrugs]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[OrderDrugs](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CreatedOn] [datetime2](7) NOT NULL,
	[Quantity] [int] NOT NULL,
	[DrugsId] [int] NOT NULL,
	[OrderId] [int] NOT NULL,
 CONSTRAINT [PK_OrderDrugs] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Patient]

-- %%
/****** Object:  Table [dbo].[Patient]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Patient](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CreatedOn] [datetime2](7) NOT NULL,
	[UserId] [int] NOT NULL,
	[Liters] [float] NULL,
	[SubscriptionValidation] [datetime2](7) NULL,
 CONSTRAINT [PK_Patient] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PatientDrugs]

-- %%
/****** Object:  Table [dbo].[PatientDrugs]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PatientDrugs](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CreatedOn] [datetime2](7) NOT NULL,
	[PatientId] [int] NOT NULL,
	[ScheduleId] [int] NOT NULL,
	[StartDate] [datetime2](7) NOT NULL,
	[EndDate] [datetime2](7) NULL,
	[DrugName] [nvarchar](max) NOT NULL,
 CONSTRAINT [PK_PatientDrugs] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Roles]

-- %%
/****** Object:  Table [dbo].[Roles]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Roles](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CreatedOn] [datetime2](7) NOT NULL,
	[Name] [nvarchar](50) NOT NULL,
 CONSTRAINT [PK_Roles] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ScheduleEnum]

-- %%
/****** Object:  Table [dbo].[ScheduleEnum]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ScheduleEnum](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CreatedOn] [datetime2](7) NOT NULL,
	[ValueName] [nvarchar](100) NOT NULL,
 CONSTRAINT [PK_ScheduleEnum] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[StatusOrderEnum]

-- %%
/****** Object:  Table [dbo].[StatusOrderEnum]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[StatusOrderEnum](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CreatedOn] [datetime2](7) NOT NULL,
	[Status] [nvarchar](max) NOT NULL,
 CONSTRAINT [PK_StatusOrderEnum] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SubscribeType]

-- %%
/****** Object:  Table [dbo].[SubscribeType]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SubscribeType](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CreatedOn] [datetime2](7) NOT NULL,
	[Type] [nvarchar](150) NOT NULL,
	[SubscribePrice] [float] NOT NULL,
	[SubscribeDescription] [nvarchar](1000) NOT NULL,
	[Days] [int] NOT NULL,
 CONSTRAINT [PK_SubscribeType] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Subscription]

-- %%
/****** Object:  Table [dbo].[Subscription]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Subscription](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CreatedOn] [datetime2](7) NOT NULL,
	[PatientId] [int] NOT NULL,
	[SubscribeTypeId] [int] NOT NULL,
 CONSTRAINT [PK_Subscription] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[User]

-- %%
/****** Object:  Table [dbo].[User]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[User](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CreatedOn] [datetime2](7) NOT NULL,
	[Email] [nvarchar](150) NOT NULL,
	[PasswordHash] [nvarchar](100) NOT NULL,
	[PhoneNumber] [nvarchar](15) NOT NULL,
	[FirstName] [nvarchar](50) NOT NULL,
	[LastName] [nvarchar](50) NOT NULL,
	[ProfilePicturePath] [nvarchar](250) NULL,
	[LocationId] [int] NULL,
	[EmployeeId] [int] NULL,
	[PatientId] [int] NULL,
 CONSTRAINT [PK_User] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[UserLogins]

-- %%
/****** Object:  Table [dbo].[UserLogins]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[UserLogins](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CreatedOn] [datetime2](7) NOT NULL,
	[LoginProvider] [nvarchar](max) NULL,
	[ProviderKey] [nvarchar](max) NULL,
	[ProviderDisplayName] [nvarchar](max) NULL,
	[UserId] [int] NOT NULL,
 CONSTRAINT [PK_UserLogins] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[UserRoles]

-- %%
/****** Object:  Table [dbo].[UserRoles]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[UserRoles](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CreatedOn] [datetime2](7) NOT NULL,
	[UserId] [int] NOT NULL,
	[RoleId] [int] NOT NULL,
 CONSTRAINT [PK_UserRoles] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[UserTokens]

-- %%
/****** Object:  Table [dbo].[UserTokens]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[UserTokens](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CreatedOn] [datetime2](7) NOT NULL,
	[UserId] [int] NOT NULL,
	[LoginProvider] [nvarchar](max) NULL,
	[Name] [nvarchar](max) NULL,
	[Value] [nvarchar](max) NULL,
 CONSTRAINT [PK_UserTokens] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Work]

-- %%
/****** Object:  Table [dbo].[Work]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Work](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CreatedOn] [datetime2](7) NOT NULL,
	[StartDate] [datetime2](7) NOT NULL,
	[EndDate] [datetime2](7) NULL,
	[EmployeeId] [int] NOT NULL,
 CONSTRAINT [PK_Work] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_Cart_Drug_DrugId]

-- %%
ALTER TABLE [dbo].[Cart]  WITH CHECK ADD  CONSTRAINT [FK_Cart_Drug_DrugId] FOREIGN KEY([DrugId])
REFERENCES [dbo].[Drug] ([Id])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Cart] CHECK CONSTRAINT [FK_Cart_Drug_DrugId]
GO

-- %% [markdown]
-- # [FK_Cart_Patient_PatientId]

-- %%
ALTER TABLE [dbo].[Cart]  WITH CHECK ADD  CONSTRAINT [FK_Cart_Patient_PatientId] FOREIGN KEY([PatientId])
REFERENCES [dbo].[Patient] ([Id])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Cart] CHECK CONSTRAINT [FK_Cart_Patient_PatientId]
GO

-- %% [markdown]
-- # [FK_Delivery_User_UserId]

-- %%
ALTER TABLE [dbo].[Delivery]  WITH CHECK ADD  CONSTRAINT [FK_Delivery_User_UserId] FOREIGN KEY([UserId])
REFERENCES [dbo].[User] ([Id])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Delivery] CHECK CONSTRAINT [FK_Delivery_User_UserId]
GO

-- %% [markdown]
-- # [FK_Drug_DrugCategory_DrugCategoryId]

-- %%
ALTER TABLE [dbo].[Drug]  WITH CHECK ADD  CONSTRAINT [FK_Drug_DrugCategory_DrugCategoryId] FOREIGN KEY([DrugCategoryId])
REFERENCES [dbo].[DrugCategory] ([Id])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Drug] CHECK CONSTRAINT [FK_Drug_DrugCategory_DrugCategoryId]
GO

-- %% [markdown]
-- # [FK_DrugDoseTime_PatientDrugs_PatientDrugId]

-- %%
ALTER TABLE [dbo].[DrugDoseTime]  WITH CHECK ADD  CONSTRAINT [FK_DrugDoseTime_PatientDrugs_PatientDrugId] FOREIGN KEY([PatientDrugId])
REFERENCES [dbo].[PatientDrugs] ([Id])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[DrugDoseTime] CHECK CONSTRAINT [FK_DrugDoseTime_PatientDrugs_PatientDrugId]
GO

-- %% [markdown]
-- # [FK_Employee_User_UserId]

-- %%
ALTER TABLE [dbo].[Employee]  WITH CHECK ADD  CONSTRAINT [FK_Employee_User_UserId] FOREIGN KEY([UserId])
REFERENCES [dbo].[User] ([Id])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Employee] CHECK CONSTRAINT [FK_Employee_User_UserId]
GO

-- %% [markdown]
-- # [FK_HealthReport_HealthReportTypes_TypeId]

-- %%
ALTER TABLE [dbo].[HealthReport]  WITH CHECK ADD  CONSTRAINT [FK_HealthReport_HealthReportTypes_TypeId] FOREIGN KEY([TypeId])
REFERENCES [dbo].[HealthReportTypes] ([Id])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[HealthReport] CHECK CONSTRAINT [FK_HealthReport_HealthReportTypes_TypeId]
GO

-- %% [markdown]
-- # [FK_HealthReport_Patient_PatientId]

-- %%
ALTER TABLE [dbo].[HealthReport]  WITH CHECK ADD  CONSTRAINT [FK_HealthReport_Patient_PatientId] FOREIGN KEY([PatientId])
REFERENCES [dbo].[Patient] ([Id])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[HealthReport] CHECK CONSTRAINT [FK_HealthReport_Patient_PatientId]
GO

-- %% [markdown]
-- # [FK_Notification_NotificationTypes_NotificationTypeId]

-- %%
ALTER TABLE [dbo].[Notification]  WITH CHECK ADD  CONSTRAINT [FK_Notification_NotificationTypes_NotificationTypeId] FOREIGN KEY([NotificationTypeId])
REFERENCES [dbo].[NotificationTypes] ([Id])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Notification] CHECK CONSTRAINT [FK_Notification_NotificationTypes_NotificationTypeId]
GO

-- %% [markdown]
-- # [FK_Notification_Patient_PatientId]

-- %%
ALTER TABLE [dbo].[Notification]  WITH CHECK ADD  CONSTRAINT [FK_Notification_Patient_PatientId] FOREIGN KEY([PatientId])
REFERENCES [dbo].[Patient] ([Id])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Notification] CHECK CONSTRAINT [FK_Notification_Patient_PatientId]
GO

-- %% [markdown]
-- # [FK_Order_Delivery_DeliveryId]

-- %%
ALTER TABLE [dbo].[Order]  WITH CHECK ADD  CONSTRAINT [FK_Order_Delivery_DeliveryId] FOREIGN KEY([DeliveryId])
REFERENCES [dbo].[Delivery] ([Id])
GO
ALTER TABLE [dbo].[Order] CHECK CONSTRAINT [FK_Order_Delivery_DeliveryId]
GO

-- %% [markdown]
-- # [FK_Order_Patient_PatientId]

-- %%
ALTER TABLE [dbo].[Order]  WITH CHECK ADD  CONSTRAINT [FK_Order_Patient_PatientId] FOREIGN KEY([PatientId])
REFERENCES [dbo].[Patient] ([Id])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Order] CHECK CONSTRAINT [FK_Order_Patient_PatientId]
GO

-- %% [markdown]
-- # [FK_Order_StatusOrderEnum_StatusId]

-- %%
ALTER TABLE [dbo].[Order]  WITH CHECK ADD  CONSTRAINT [FK_Order_StatusOrderEnum_StatusId] FOREIGN KEY([StatusId])
REFERENCES [dbo].[StatusOrderEnum] ([Id])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Order] CHECK CONSTRAINT [FK_Order_StatusOrderEnum_StatusId]
GO

-- %% [markdown]
-- # [FK_OrderDrugs_Drug_DrugsId]

-- %%
ALTER TABLE [dbo].[OrderDrugs]  WITH CHECK ADD  CONSTRAINT [FK_OrderDrugs_Drug_DrugsId] FOREIGN KEY([DrugsId])
REFERENCES [dbo].[Drug] ([Id])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[OrderDrugs] CHECK CONSTRAINT [FK_OrderDrugs_Drug_DrugsId]
GO

-- %% [markdown]
-- # [FK_OrderDrugs_Order_OrderId]

-- %%
ALTER TABLE [dbo].[OrderDrugs]  WITH CHECK ADD  CONSTRAINT [FK_OrderDrugs_Order_OrderId] FOREIGN KEY([OrderId])
REFERENCES [dbo].[Order] ([Id])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[OrderDrugs] CHECK CONSTRAINT [FK_OrderDrugs_Order_OrderId]
GO

-- %% [markdown]
-- # [FK_Patient_User_UserId]

-- %%
ALTER TABLE [dbo].[Patient]  WITH CHECK ADD  CONSTRAINT [FK_Patient_User_UserId] FOREIGN KEY([UserId])
REFERENCES [dbo].[User] ([Id])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Patient] CHECK CONSTRAINT [FK_Patient_User_UserId]
GO

-- %% [markdown]
-- # [FK_PatientDrugs_Patient_PatientId]

-- %%
ALTER TABLE [dbo].[PatientDrugs]  WITH CHECK ADD  CONSTRAINT [FK_PatientDrugs_Patient_PatientId] FOREIGN KEY([PatientId])
REFERENCES [dbo].[Patient] ([Id])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[PatientDrugs] CHECK CONSTRAINT [FK_PatientDrugs_Patient_PatientId]
GO

-- %% [markdown]
-- # [FK_PatientDrugs_ScheduleEnum_ScheduleId]

-- %%
ALTER TABLE [dbo].[PatientDrugs]  WITH CHECK ADD  CONSTRAINT [FK_PatientDrugs_ScheduleEnum_ScheduleId] FOREIGN KEY([ScheduleId])
REFERENCES [dbo].[ScheduleEnum] ([Id])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[PatientDrugs] CHECK CONSTRAINT [FK_PatientDrugs_ScheduleEnum_ScheduleId]
GO

-- %% [markdown]
-- # [FK_Subscription_Patient_PatientId]

-- %%
ALTER TABLE [dbo].[Subscription]  WITH CHECK ADD  CONSTRAINT [FK_Subscription_Patient_PatientId] FOREIGN KEY([PatientId])
REFERENCES [dbo].[Patient] ([Id])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Subscription] CHECK CONSTRAINT [FK_Subscription_Patient_PatientId]
GO

-- %% [markdown]
-- # [FK_Subscription_SubscribeType_SubscribeTypeId]

-- %%
ALTER TABLE [dbo].[Subscription]  WITH CHECK ADD  CONSTRAINT [FK_Subscription_SubscribeType_SubscribeTypeId] FOREIGN KEY([SubscribeTypeId])
REFERENCES [dbo].[SubscribeType] ([Id])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Subscription] CHECK CONSTRAINT [FK_Subscription_SubscribeType_SubscribeTypeId]
GO

-- %% [markdown]
-- # [FK_User_Location_LocationId]

-- %%
ALTER TABLE [dbo].[User]  WITH CHECK ADD  CONSTRAINT [FK_User_Location_LocationId] FOREIGN KEY([LocationId])
REFERENCES [dbo].[Location] ([Id])
GO
ALTER TABLE [dbo].[User] CHECK CONSTRAINT [FK_User_Location_LocationId]
GO

-- %% [markdown]
-- # [FK_UserLogins_User_UserId]

-- %%
ALTER TABLE [dbo].[UserLogins]  WITH CHECK ADD  CONSTRAINT [FK_UserLogins_User_UserId] FOREIGN KEY([UserId])
REFERENCES [dbo].[User] ([Id])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[UserLogins] CHECK CONSTRAINT [FK_UserLogins_User_UserId]
GO

-- %% [markdown]
-- # [FK_UserRoles_Roles_RoleId]

-- %%
ALTER TABLE [dbo].[UserRoles]  WITH CHECK ADD  CONSTRAINT [FK_UserRoles_Roles_RoleId] FOREIGN KEY([RoleId])
REFERENCES [dbo].[Roles] ([Id])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[UserRoles] CHECK CONSTRAINT [FK_UserRoles_Roles_RoleId]
GO

-- %% [markdown]
-- # [FK_UserRoles_User_UserId]

-- %%
ALTER TABLE [dbo].[UserRoles]  WITH CHECK ADD  CONSTRAINT [FK_UserRoles_User_UserId] FOREIGN KEY([UserId])
REFERENCES [dbo].[User] ([Id])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[UserRoles] CHECK CONSTRAINT [FK_UserRoles_User_UserId]
GO

-- %% [markdown]
-- # [FK_UserTokens_User_UserId]

-- %%
ALTER TABLE [dbo].[UserTokens]  WITH CHECK ADD  CONSTRAINT [FK_UserTokens_User_UserId] FOREIGN KEY([UserId])
REFERENCES [dbo].[User] ([Id])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[UserTokens] CHECK CONSTRAINT [FK_UserTokens_User_UserId]
GO

-- %% [markdown]
-- # [FK_Work_Employee_EmployeeId]

-- %%
ALTER TABLE [dbo].[Work]  WITH CHECK ADD  CONSTRAINT [FK_Work_Employee_EmployeeId] FOREIGN KEY([EmployeeId])
REFERENCES [dbo].[Employee] ([Id])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Work] CHECK CONSTRAINT [FK_Work_Employee_EmployeeId]
GO

-- %% [markdown]
-- # [dbo].[AddOrUpdateProfilePicture]

-- %%
/****** Object:  StoredProcedure [dbo].[AddOrUpdateProfilePicture]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[AddOrUpdateProfilePicture]
@imagePath varchar(250), 
@userId int
as 
begin 
update [User]
set ProfilePicturePath = @imagePath
where Id = @userId
end 
GO

-- %% [markdown]
-- # [dbo].[AuthLogin]

-- %%
/****** Object:  StoredProcedure [dbo].[AuthLogin]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[AuthLogin]
@Email varchar(50)
as 
select  u.FirstName as "FirstName", u.Email as "Email" , u.Id as "Id"
from [User] as u
where u.Email = @Email 
GO

-- %% [markdown]
-- # [dbo].[CartDelete]

-- %%
/****** Object:  StoredProcedure [dbo].[CartDelete]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[CartDelete] 
    @Id int
AS 

	DELETE
	FROM   [dbo].[Cart]
	WHERE  [Id] = @Id

GO

-- %% [markdown]
-- # [dbo].[CartGetAll]

-- %%
/****** Object:  StoredProcedure [dbo].[CartGetAll]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[CartGetAll]
as 
begin 
select * from Cart
end
GO

-- %% [markdown]
-- # [dbo].[CartInsert]

-- %%
/****** Object:  StoredProcedure [dbo].[CartInsert]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[CartInsert] 
    @CreatedOn datetime2(7),
    @PatientId int,
    @DrugId int
AS 

	INSERT INTO [dbo].[Cart] ([CreatedOn], [PatientId], [DrugId])
	SELECT @CreatedOn, @PatientId, @DrugId
	
GO

-- %% [markdown]
-- # [dbo].[CartSelect]

-- %%
/****** Object:  StoredProcedure [dbo].[CartSelect]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
----------------------------------------------------------------------------------------
----------------------------------------------------------------------------------------

CREATE PROC [dbo].[CartSelect] 
    @Id int
AS 

	SELECT [Id], [CreatedOn], [PatientId], [DrugId] 
	FROM   [dbo].[Cart] 
	WHERE  ([Id] = @Id OR @Id IS NULL) 

GO

-- %% [markdown]
-- # [dbo].[CartUpdate]

-- %%
/****** Object:  StoredProcedure [dbo].[CartUpdate]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[CartUpdate] 
    @Id int,
    @CreatedOn datetime2(7),
    @PatientId int,
    @DrugId int
AS 

	UPDATE [dbo].[Cart]
	SET    [CreatedOn] = @CreatedOn, [PatientId] = @PatientId, [DrugId] = @DrugId
	WHERE  [Id] = @Id
	
GO

-- %% [markdown]
-- # [dbo].[CheckEmailExist]

-- %%
/****** Object:  StoredProcedure [dbo].[CheckEmailExist]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[CheckEmailExist]
@Email varchar(150)
as 
begin 
select u.Id  from [User]as u 
where u.Email = @Email
end 
GO

-- %% [markdown]
-- # [dbo].[DeliveryDelete]

-- %%
/****** Object:  StoredProcedure [dbo].[DeliveryDelete]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[DeliveryDelete] 
    @Id int
AS 

	DELETE
	FROM   [dbo].[Delivery]
	WHERE  [Id] = @Id

GO

-- %% [markdown]
-- # [dbo].[DeliveryGetAll]

-- %%
/****** Object:  StoredProcedure [dbo].[DeliveryGetAll]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[DeliveryGetAll]
as 
begin 
select * from Delivery
end
GO

-- %% [markdown]
-- # [dbo].[DeliveryInsert]

-- %%
/****** Object:  StoredProcedure [dbo].[DeliveryInsert]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[DeliveryInsert] 
    @CreatedOn datetime2(7),
    @UserId int
AS 

	INSERT INTO [dbo].[Delivery] ([CreatedOn], [UserId])
	SELECT @CreatedOn, @UserId
	
GO

-- %% [markdown]
-- # [dbo].[DeliverySelect]

-- %%
/****** Object:  StoredProcedure [dbo].[DeliverySelect]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
----------------------------------------------------------------------------------------
----------------------------------------------------------------------------------------

CREATE PROC [dbo].[DeliverySelect] 
    @Id int
AS 

	SELECT [Id], [CreatedOn], [UserId] 
	FROM   [dbo].[Delivery] 
	WHERE  ([Id] = @Id OR @Id IS NULL) 

GO

-- %% [markdown]
-- # [dbo].[DeliveryUpdate]

-- %%
/****** Object:  StoredProcedure [dbo].[DeliveryUpdate]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[DeliveryUpdate] 
    @Id int,
    @CreatedOn datetime2(7),
    @UserId int
AS 

	UPDATE [dbo].[Delivery]
	SET    [CreatedOn] = @CreatedOn, [UserId] = @UserId
	WHERE  [Id] = @Id
	
GO

-- %% [markdown]
-- # [dbo].[DrugCategoryDelete]

-- %%
/****** Object:  StoredProcedure [dbo].[DrugCategoryDelete]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[DrugCategoryDelete] 
    @Id int
AS 

	DELETE
	FROM   [dbo].[DrugCategory]
	WHERE  [Id] = @Id

GO

-- %% [markdown]
-- # [dbo].[DrugCategoryGetAll]

-- %%
/****** Object:  StoredProcedure [dbo].[DrugCategoryGetAll]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[DrugCategoryGetAll]
as 
begin 
select * from DrugCategory
end
GO

-- %% [markdown]
-- # [dbo].[DrugCategoryInsert]

-- %%
/****** Object:  StoredProcedure [dbo].[DrugCategoryInsert]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[DrugCategoryInsert] 
    @CreatedOn datetime2(7),
    @Name nvarchar(100),
    @PicturePath nvarchar(250) = NULL
AS 

	INSERT INTO [dbo].[DrugCategory] ([CreatedOn], [Name], [PicturePath])
	SELECT @CreatedOn, @Name, @PicturePath
	
GO

-- %% [markdown]
-- # [dbo].[DrugCategorySelect]

-- %%
/****** Object:  StoredProcedure [dbo].[DrugCategorySelect]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
----------------------------------------------------------------------------------------
----------------------------------------------------------------------------------------

CREATE PROC [dbo].[DrugCategorySelect] 
    @Id int
AS 

	SELECT [Id], [CreatedOn], [Name], [PicturePath] 
	FROM   [dbo].[DrugCategory] 
	WHERE  ([Id] = @Id OR @Id IS NULL) 

GO

-- %% [markdown]
-- # [dbo].[DrugCategoryUpdate]

-- %%
/****** Object:  StoredProcedure [dbo].[DrugCategoryUpdate]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[DrugCategoryUpdate] 
    @Id int,
    @Name nvarchar(100),
    @PicturePath nvarchar(250) 
AS 
if(@PicturePath = '0')
	UPDATE [dbo].[DrugCategory]
	SET    [Name] = @Name
	WHERE  [Id] = @Id
else
	UPDATE [dbo].[DrugCategory]
	SET    [Name] = @Name, [PicturePath] = @PicturePath
	WHERE  [Id] = @Id
GO

-- %% [markdown]
-- # [dbo].[DrugDelete]

-- %%
/****** Object:  StoredProcedure [dbo].[DrugDelete]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[DrugDelete] 
    @Id int
AS 

	DELETE
	FROM   [dbo].[Drug]
	WHERE  [Id] = @Id

GO

-- %% [markdown]
-- # [dbo].[DrugDoseTimeDelete]

-- %%
/****** Object:  StoredProcedure [dbo].[DrugDoseTimeDelete]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[DrugDoseTimeDelete] 
    @Id int
AS 

	DELETE
	FROM   [dbo].[DrugDoseTime]
	WHERE  [Id] = @Id

GO

-- %% [markdown]
-- # [dbo].[DrugDoseTimeGetAll]

-- %%
/****** Object:  StoredProcedure [dbo].[DrugDoseTimeGetAll]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[DrugDoseTimeGetAll]
as 
begin 
select * from DrugDoseTime
end
GO

-- %% [markdown]
-- # [dbo].[DrugDoseTimeInsert]

-- %%
/****** Object:  StoredProcedure [dbo].[DrugDoseTimeInsert]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[DrugDoseTimeInsert] 
    @CreatedOn datetime2(7),
    @PatientDrugId int,
    @Time time(7)
AS 

	INSERT INTO [dbo].[DrugDoseTime] ([CreatedOn], [PatientDrugId], [Time])
	SELECT @CreatedOn, @PatientDrugId, @Time
	
GO

-- %% [markdown]
-- # [dbo].[DrugDoseTimeSelect]

-- %%
/****** Object:  StoredProcedure [dbo].[DrugDoseTimeSelect]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
----------------------------------------------------------------------------------------
----------------------------------------------------------------------------------------

CREATE PROC [dbo].[DrugDoseTimeSelect] 
    @Id int
AS 

	SELECT [Id], [CreatedOn], [PatientDrugId], [Time] 
	FROM   [dbo].[DrugDoseTime] 
	WHERE  ([Id] = @Id OR @Id IS NULL) 

GO

-- %% [markdown]
-- # [dbo].[DrugDoseTimeUpdate]

-- %%
/****** Object:  StoredProcedure [dbo].[DrugDoseTimeUpdate]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[DrugDoseTimeUpdate] 
    @Id int,
    @CreatedOn datetime2(7),
    @PatientDrugId int,
    @Time time(7)
AS 

	UPDATE [dbo].[DrugDoseTime]
	SET    [CreatedOn] = @CreatedOn, [PatientDrugId] = @PatientDrugId, [Time] = @Time
	WHERE  [Id] = @Id
	
GO

-- %% [markdown]
-- # [dbo].[DrugGetAll]

-- %%
/****** Object:  StoredProcedure [dbo].[DrugGetAll]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[DrugGetAll]
as 
begin 
select * from Drug
end
GO

-- %% [markdown]
-- # [dbo].[DrugInsert]

-- %%
/****** Object:  StoredProcedure [dbo].[DrugInsert]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[DrugInsert] 
    @CreatedOn datetime2(7),
    @DrugCategoryId int,
    @Name nvarchar(150),
    @Price float,
    @PicturePath nvarchar(250) = NULL
AS 

	INSERT INTO [dbo].[Drug] ([CreatedOn], [DrugCategoryId], [Name], [Price], [PicturePath])
	SELECT @CreatedOn, @DrugCategoryId, @Name, @Price, @PicturePath
	
GO

-- %% [markdown]
-- # [dbo].[DrugSelect]

-- %%
/****** Object:  StoredProcedure [dbo].[DrugSelect]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
----------------------------------------------------------------------------------------
----------------------------------------------------------------------------------------

CREATE PROC [dbo].[DrugSelect] 
    @Id int
AS 

	SELECT [Id], [CreatedOn], [DrugCategoryId], [Name], [Price], [PicturePath] 
	FROM   [dbo].[Drug] 
	WHERE  ([Id] = @Id OR @Id IS NULL) 

GO

-- %% [markdown]
-- # [dbo].[DrugUpdate]

-- %%
/****** Object:  StoredProcedure [dbo].[DrugUpdate]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[DrugUpdate] 
    @Id int,
    @CreatedOn datetime2(7),
    @DrugCategoryId int,
    @Name nvarchar(150),
    @Price float,
    @PicturePath nvarchar(250) = NULL
AS 

	UPDATE [dbo].[Drug]
	SET    [CreatedOn] = @CreatedOn, [DrugCategoryId] = @DrugCategoryId, [Name] = @Name, [Price] = @Price, [PicturePath] = @PicturePath
	WHERE  [Id] = @Id
	
GO

-- %% [markdown]
-- # [dbo].[EmployeeDelete]

-- %%
/****** Object:  StoredProcedure [dbo].[EmployeeDelete]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[EmployeeDelete] 
    @Id int
AS 

	DELETE
	FROM   [dbo].[Employee]
	WHERE  [Id] = @Id

GO

-- %% [markdown]
-- # [dbo].[EmployeeInsert]

-- %%
/****** Object:  StoredProcedure [dbo].[EmployeeInsert]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[EmployeeInsert] 
    @CreatedOn datetime2(7),
    @HourSalary float,
    @MonthlyWorkingHours int,
    @PricePerHour float = NULL,
    @UserId int
AS 

	INSERT INTO [dbo].[Employee] ([CreatedOn], [HourSalary], [MonthlyWorkingHours], [PricePerHour], [UserId])
	SELECT @CreatedOn, @HourSalary, @MonthlyWorkingHours, @PricePerHour, @UserId
	
GO

-- %% [markdown]
-- # [dbo].[EmployeeSelect]

-- %%
/****** Object:  StoredProcedure [dbo].[EmployeeSelect]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
----------------------------------------------------------------------------------------
----------------------------------------------------------------------------------------

CREATE PROC [dbo].[EmployeeSelect] 
    @Id int
AS 

	SELECT [Id], [CreatedOn], [HourSalary], [MonthlyWorkingHours], [PricePerHour], [UserId] 
	FROM   [dbo].[Employee] 
	WHERE  ([Id] = @Id OR @Id IS NULL) 

GO

-- %% [markdown]
-- # [dbo].[EmployeesGetAll]

-- %%
/****** Object:  StoredProcedure [dbo].[EmployeesGetAll]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[EmployeesGetAll]
as 
begin 
select * from Employee
end
GO

-- %% [markdown]
-- # [dbo].[EmployeeUpdate]

-- %%
/****** Object:  StoredProcedure [dbo].[EmployeeUpdate]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[EmployeeUpdate] 
    @Id int,
    @CreatedOn datetime2(7),
    @HourSalary float,
    @MonthlyWorkingHours int,
    @PricePerHour float = NULL,
    @UserId int
AS 

	UPDATE [dbo].[Employee]
	SET    [CreatedOn] = @CreatedOn, [HourSalary] = @HourSalary, [MonthlyWorkingHours] = @MonthlyWorkingHours, [PricePerHour] = @PricePerHour, [UserId] = @UserId
	WHERE  [Id] = @Id
	
GO

-- %% [markdown]
-- # [dbo].[GetAllEmployees]

-- %%
/****** Object:  StoredProcedure [dbo].[GetAllEmployees]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[GetAllEmployees]
as begin 
select * from Employee
end
GO

-- %% [markdown]
-- # [dbo].[GetAllUserLogins]

-- %%
/****** Object:  StoredProcedure [dbo].[GetAllUserLogins]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[GetAllUserLogins]
as begin 
select * from UserLogins
end
GO

-- %% [markdown]
-- # [dbo].[GetAllUserRole]

-- %%
/****** Object:  StoredProcedure [dbo].[GetAllUserRole]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[GetAllUserRole]
as 
begin 
select * from UserRoles 
end
GO

-- %% [markdown]
-- # [dbo].[GetAllUsers]

-- %%
/****** Object:  StoredProcedure [dbo].[GetAllUsers]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[GetAllUsers]
as 
begin

select * from [dbo].[User]

end
GO

-- %% [markdown]
-- # [dbo].[GetAllUserTokens]

-- %%
/****** Object:  StoredProcedure [dbo].[GetAllUserTokens]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[GetAllUserTokens]
as begin 
select * from UserTokens
end
GO

-- %% [markdown]
-- # [dbo].[GetPasswordByEmail]

-- %%
/****** Object:  StoredProcedure [dbo].[GetPasswordByEmail]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[GetPasswordByEmail]
@Email varchar(150)
as 
select u.PasswordHash from [User] as u
where u.Email = @Email
GO

-- %% [markdown]
-- # [dbo].[GetRoleIdByName]

-- %%
/****** Object:  StoredProcedure [dbo].[GetRoleIdByName]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[GetRoleIdByName]
@Name varchar(50)
as 
select r.Id from Roles as r
where r.Name = @Name
GO

-- %% [markdown]
-- # [dbo].[GetUserByEmail]

-- %%
/****** Object:  StoredProcedure [dbo].[GetUserByEmail]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[GetUserByEmail]
@Email varchar(150)
as 
select * from [User] as u 
where u.Email = @Email
GO

-- %% [markdown]
-- # [dbo].[GetUserRoles]

-- %%
/****** Object:  StoredProcedure [dbo].[GetUserRoles]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[GetUserRoles]
@Id int 
as
begin 
select r.Name  from UserRoles as ur , Roles as r
where ur.UserId = @Id and ur.RoleId = r.Id
end
GO

-- %% [markdown]
-- # [dbo].[HealthReportDelete]

-- %%
/****** Object:  StoredProcedure [dbo].[HealthReportDelete]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[HealthReportDelete] 
    @Id int
AS 

	DELETE
	FROM   [dbo].[HealthReport]
	WHERE  [Id] = @Id

GO

-- %% [markdown]
-- # [dbo].[HealthReportGetAll]

-- %%
/****** Object:  StoredProcedure [dbo].[HealthReportGetAll]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[HealthReportGetAll]
as 
begin 
select * from HealthReport
end
GO

-- %% [markdown]
-- # [dbo].[HealthReportInsert]

-- %%
/****** Object:  StoredProcedure [dbo].[HealthReportInsert]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[HealthReportInsert] 
    @CreatedOn datetime2(7),
    @PatientId int,
    @TypeId int,
    @Value float
AS 

	INSERT INTO [dbo].[HealthReport] ([CreatedOn], [PatientId], [TypeId], [Value])
	SELECT @CreatedOn, @PatientId, @TypeId, @Value
	
GO

-- %% [markdown]
-- # [dbo].[HealthReportSelect]

-- %%
/****** Object:  StoredProcedure [dbo].[HealthReportSelect]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
----------------------------------------------------------------------------------------
----------------------------------------------------------------------------------------

CREATE PROC [dbo].[HealthReportSelect] 
    @Id int
AS 

	SELECT [Id], [CreatedOn], [PatientId], [TypeId], [Value] 
	FROM   [dbo].[HealthReport] 
	WHERE  ([Id] = @Id OR @Id IS NULL) 

GO

-- %% [markdown]
-- # [dbo].[HealthReportTypesDelete]

-- %%
/****** Object:  StoredProcedure [dbo].[HealthReportTypesDelete]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[HealthReportTypesDelete] 
    @Id int
AS 

	DELETE
	FROM   [dbo].[HealthReportTypes]
	WHERE  [Id] = @Id

GO

-- %% [markdown]
-- # [dbo].[HealthReportTypesGetAll]

-- %%
/****** Object:  StoredProcedure [dbo].[HealthReportTypesGetAll]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[HealthReportTypesGetAll]
as 
begin 
select * from HealthReportTypes
end
GO

-- %% [markdown]
-- # [dbo].[HealthReportTypesInsert]

-- %%
/****** Object:  StoredProcedure [dbo].[HealthReportTypesInsert]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[HealthReportTypesInsert] 
    @CreatedOn datetime2(7),
    @Type nvarchar(150)
AS 

	INSERT INTO [dbo].[HealthReportTypes] ([CreatedOn], [Type])
	SELECT @CreatedOn, @Type
	
GO

-- %% [markdown]
-- # [dbo].[HealthReportTypesSelect]

-- %%
/****** Object:  StoredProcedure [dbo].[HealthReportTypesSelect]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
----------------------------------------------------------------------------------------
----------------------------------------------------------------------------------------

CREATE PROC [dbo].[HealthReportTypesSelect] 
    @Id int
AS 

	SELECT [Id], [CreatedOn], [Type] 
	FROM   [dbo].[HealthReportTypes] 
	WHERE  ([Id] = @Id OR @Id IS NULL) 

GO

-- %% [markdown]
-- # [dbo].[HealthReportTypesUpdate]

-- %%
/****** Object:  StoredProcedure [dbo].[HealthReportTypesUpdate]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[HealthReportTypesUpdate] 
    @Id int,
    @CreatedOn datetime2(7),
    @Type nvarchar(150)
AS 

	UPDATE [dbo].[HealthReportTypes]
	SET    [CreatedOn] = @CreatedOn, [Type] = @Type
	WHERE  [Id] = @Id
	
GO

-- %% [markdown]
-- # [dbo].[HealthReportUpdate]

-- %%
/****** Object:  StoredProcedure [dbo].[HealthReportUpdate]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[HealthReportUpdate] 
    @Id int,
    @CreatedOn datetime2(7),
    @PatientId int,
    @TypeId int,
    @Value float
AS 

	UPDATE [dbo].[HealthReport]
	SET    [CreatedOn] = @CreatedOn, [PatientId] = @PatientId, [TypeId] = @TypeId, [Value] = @Value
	WHERE  [Id] = @Id
	
GO

-- %% [markdown]
-- # [dbo].[LocationDelete]

-- %%
/****** Object:  StoredProcedure [dbo].[LocationDelete]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[LocationDelete] 
    @Id int
AS 

	DELETE
	FROM   [dbo].[Location]
	WHERE  [Id] = @Id

GO

-- %% [markdown]
-- # [dbo].[LocationInsert]

-- %%
/****** Object:  StoredProcedure [dbo].[LocationInsert]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[LocationInsert] 
    @CreatedOn datetime2(7),
    @location nvarchar(MAX) = NULL
AS 

	INSERT INTO [dbo].[Location] ([CreatedOn], [location])
	SELECT @CreatedOn, @location
	
GO

-- %% [markdown]
-- # [dbo].[LocationSelect]

-- %%
/****** Object:  StoredProcedure [dbo].[LocationSelect]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
----------------------------------------------------------------------------------------
----------------------------------------------------------------------------------------

CREATE PROC [dbo].[LocationSelect] 
    @Id int
AS 

	SELECT [Id], [CreatedOn], [location] 
	FROM   [dbo].[Location] 
	WHERE  ([Id] = @Id OR @Id IS NULL) 

GO

-- %% [markdown]
-- # [dbo].[LocationUpdate]

-- %%
/****** Object:  StoredProcedure [dbo].[LocationUpdate]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[LocationUpdate] 
    @Id int,
    @CreatedOn datetime2(7),
    @location nvarchar(MAX) = NULL
AS 

	UPDATE [dbo].[Location]
	SET    [CreatedOn] = @CreatedOn, [location] = @location
	WHERE  [Id] = @Id
	
GO

-- %% [markdown]
-- # [dbo].[NotificationDelete]

-- %%
/****** Object:  StoredProcedure [dbo].[NotificationDelete]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[NotificationDelete] 
    @Id int
AS 

	DELETE
	FROM   [dbo].[Notification]
	WHERE  [Id] = @Id

GO

-- %% [markdown]
-- # [dbo].[NotificationGetAll]

-- %%
/****** Object:  StoredProcedure [dbo].[NotificationGetAll]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[NotificationGetAll]
as 
begin 
select * from [Notification]
end
GO

-- %% [markdown]
-- # [dbo].[NotificationInsert]

-- %%
/****** Object:  StoredProcedure [dbo].[NotificationInsert]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[NotificationInsert] 
    @CreatedOn datetime2(7),
    @Message nvarchar(1500),
    @PatientId int,
    @NotificationTypeId int
AS 

	INSERT INTO [dbo].[Notification] ([CreatedOn], [Message], [PatientId], [NotificationTypeId])
	SELECT @CreatedOn, @Message, @PatientId, @NotificationTypeId
	
GO

-- %% [markdown]
-- # [dbo].[NotificationSelect]

-- %%
/****** Object:  StoredProcedure [dbo].[NotificationSelect]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
----------------------------------------------------------------------------------------
----------------------------------------------------------------------------------------

CREATE PROC [dbo].[NotificationSelect] 
    @Id int
AS 

	SELECT [Id], [CreatedOn], [Message], [PatientId], [NotificationTypeId] 
	FROM   [dbo].[Notification] 
	WHERE  ([Id] = @Id OR @Id IS NULL) 

GO

-- %% [markdown]
-- # [dbo].[NotificationTypesDelete]

-- %%
/****** Object:  StoredProcedure [dbo].[NotificationTypesDelete]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[NotificationTypesDelete] 
    @Id int
AS 

	DELETE
	FROM   [dbo].[NotificationTypes]
	WHERE  [Id] = @Id

GO

-- %% [markdown]
-- # [dbo].[NotificationTypesInsert]

-- %%
/****** Object:  StoredProcedure [dbo].[NotificationTypesInsert]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[NotificationTypesInsert] 
    @CreatedOn datetime2(7),
    @Type nvarchar(150)
AS 

	INSERT INTO [dbo].[NotificationTypes] ([CreatedOn], [Type])
	SELECT @CreatedOn, @Type
	
GO

-- %% [markdown]
-- # [dbo].[NotificationTypesSelect]

-- %%
/****** Object:  StoredProcedure [dbo].[NotificationTypesSelect]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
----------------------------------------------------------------------------------------
----------------------------------------------------------------------------------------

CREATE PROC [dbo].[NotificationTypesSelect] 
    @Id int
AS 

	SELECT [Id], [CreatedOn], [Type] 
	FROM   [dbo].[NotificationTypes] 
	WHERE  ([Id] = @Id OR @Id IS NULL) 

GO

-- %% [markdown]
-- # [dbo].[NotificationTypesUpdate]

-- %%
/****** Object:  StoredProcedure [dbo].[NotificationTypesUpdate]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[NotificationTypesUpdate] 
    @Id int,
    @CreatedOn datetime2(7),
    @Type nvarchar(150)
AS 

	UPDATE [dbo].[NotificationTypes]
	SET    [CreatedOn] = @CreatedOn, [Type] = @Type
	WHERE  [Id] = @Id
	
GO

-- %% [markdown]
-- # [dbo].[NotificationUpdate]

-- %%
/****** Object:  StoredProcedure [dbo].[NotificationUpdate]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[NotificationUpdate] 
    @Id int,
    @CreatedOn datetime2(7),
    @Message nvarchar(1500),
    @PatientId int,
    @NotificationTypeId int
AS 

	UPDATE [dbo].[Notification]
	SET    [CreatedOn] = @CreatedOn, [Message] = @Message, [PatientId] = @PatientId, [NotificationTypeId] = @NotificationTypeId
	WHERE  [Id] = @Id
	
GO

-- %% [markdown]
-- # [dbo].[OrderDelete]

-- %%
/****** Object:  StoredProcedure [dbo].[OrderDelete]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[OrderDelete] 
    @Id int
AS 

	DELETE
	FROM   [dbo].[Order]
	WHERE  [Id] = @Id

GO

-- %% [markdown]
-- # [dbo].[OrderDrugsDelete]

-- %%
/****** Object:  StoredProcedure [dbo].[OrderDrugsDelete]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[OrderDrugsDelete] 
    @Id int
AS 

	DELETE
	FROM   [dbo].[OrderDrugs]
	WHERE  [Id] = @Id

GO

-- %% [markdown]
-- # [dbo].[OrderDrugsGetAll]

-- %%
/****** Object:  StoredProcedure [dbo].[OrderDrugsGetAll]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[OrderDrugsGetAll]
as 
begin 
select * from OrderDrugs
end
GO

-- %% [markdown]
-- # [dbo].[OrderDrugsInsert]

-- %%
/****** Object:  StoredProcedure [dbo].[OrderDrugsInsert]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[OrderDrugsInsert] 
    @CreatedOn datetime2(7),
    @Quantity int,
    @DrugsId int,
    @OrderId int
AS 

	INSERT INTO [dbo].[OrderDrugs] ([CreatedOn], [Quantity], [DrugsId], [OrderId])
	SELECT @CreatedOn, @Quantity, @DrugsId, @OrderId
	
GO

-- %% [markdown]
-- # [dbo].[OrderDrugsSelect]

-- %%
/****** Object:  StoredProcedure [dbo].[OrderDrugsSelect]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
----------------------------------------------------------------------------------------
----------------------------------------------------------------------------------------

CREATE PROC [dbo].[OrderDrugsSelect] 
    @Id int
AS 

	SELECT [Id], [CreatedOn], [Quantity], [DrugsId], [OrderId] 
	FROM   [dbo].[OrderDrugs] 
	WHERE  ([Id] = @Id OR @Id IS NULL) 

GO

-- %% [markdown]
-- # [dbo].[OrderDrugsUpdate]

-- %%
/****** Object:  StoredProcedure [dbo].[OrderDrugsUpdate]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[OrderDrugsUpdate] 
    @Id int,
    @CreatedOn datetime2(7),
    @Quantity int,
    @DrugsId int,
    @OrderId int
AS 

	UPDATE [dbo].[OrderDrugs]
	SET    [CreatedOn] = @CreatedOn, [Quantity] = @Quantity, [DrugsId] = @DrugsId, [OrderId] = @OrderId
	WHERE  [Id] = @Id
	
GO

-- %% [markdown]
-- # [dbo].[OrderGetAll]

-- %%
/****** Object:  StoredProcedure [dbo].[OrderGetAll]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[OrderGetAll]
as 
begin 
select * from [Order]
end
GO

-- %% [markdown]
-- # [dbo].[OrderInsert]

-- %%
/****** Object:  StoredProcedure [dbo].[OrderInsert]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[OrderInsert] 
    @CreatedOn datetime2(7),
    @TotalPrice float,
    @StatusId int,
    @DeliveryId int = NULL,
    @PatientId int
AS 

	INSERT INTO [dbo].[Order] ([CreatedOn], [TotalPrice], [StatusId], [DeliveryId], [PatientId])
	SELECT @CreatedOn, @TotalPrice, @StatusId, @DeliveryId, @PatientId
	
GO

-- %% [markdown]
-- # [dbo].[OrderSelect]

-- %%
/****** Object:  StoredProcedure [dbo].[OrderSelect]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
----------------------------------------------------------------------------------------
----------------------------------------------------------------------------------------

CREATE PROC [dbo].[OrderSelect] 
    @Id int
AS 

	SELECT [Id], [CreatedOn], [TotalPrice], [StatusId], [DeliveryId], [PatientId] 
	FROM   [dbo].[Order] 
	WHERE  ([Id] = @Id OR @Id IS NULL) 

GO

-- %% [markdown]
-- # [dbo].[OrderUpdate]

-- %%
/****** Object:  StoredProcedure [dbo].[OrderUpdate]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[OrderUpdate] 
    @Id int,
    @CreatedOn datetime2(7),
    @TotalPrice float,
    @StatusId int,
    @DeliveryId int = NULL,
    @PatientId int
AS 

	UPDATE [dbo].[Order]
	SET    [CreatedOn] = @CreatedOn, [TotalPrice] = @TotalPrice, [StatusId] = @StatusId, [DeliveryId] = @DeliveryId, [PatientId] = @PatientId
	WHERE  [Id] = @Id
	
GO

-- %% [markdown]
-- # [dbo].[PatientDelete]

-- %%
/****** Object:  StoredProcedure [dbo].[PatientDelete]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[PatientDelete] 
    @Id int
AS 

	DELETE
	FROM   [dbo].[Patient]
	WHERE  [Id] = @Id

GO

-- %% [markdown]
-- # [dbo].[PatientDrugsDelete]

-- %%
/****** Object:  StoredProcedure [dbo].[PatientDrugsDelete]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[PatientDrugsDelete] 
    @Id int
AS 

	DELETE
	FROM   [dbo].[PatientDrugs]
	WHERE  [Id] = @Id

GO

-- %% [markdown]
-- # [dbo].[PatientDrugsGetAll]

-- %%
/****** Object:  StoredProcedure [dbo].[PatientDrugsGetAll]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[PatientDrugsGetAll]
as 
begin 
select * from PatientDrugs
end
GO

-- %% [markdown]
-- # [dbo].[PatientDrugsInsert]

-- %%
/****** Object:  StoredProcedure [dbo].[PatientDrugsInsert]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[PatientDrugsInsert] 
    @CreatedOn datetime2(7),
    @PatientId int,
    @ScheduleId int,
    @StartDate datetime2(7),
    @EndDate datetime2(7) = NULL
AS 

	INSERT INTO [dbo].[PatientDrugs] ([CreatedOn], [PatientId], [ScheduleId], [StartDate], [EndDate])
	SELECT @CreatedOn, @PatientId, @ScheduleId, @StartDate, @EndDate
	
GO

-- %% [markdown]
-- # [dbo].[PatientDrugsSelect]

-- %%
/****** Object:  StoredProcedure [dbo].[PatientDrugsSelect]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
----------------------------------------------------------------------------------------
----------------------------------------------------------------------------------------

CREATE PROC [dbo].[PatientDrugsSelect] 
    @Id int
AS 

	SELECT [Id], [CreatedOn], [PatientId], [ScheduleId], [StartDate], [EndDate] 
	FROM   [dbo].[PatientDrugs] 
	WHERE  ([Id] = @Id OR @Id IS NULL) 

GO

-- %% [markdown]
-- # [dbo].[PatientDrugsUpdate]

-- %%
/****** Object:  StoredProcedure [dbo].[PatientDrugsUpdate]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[PatientDrugsUpdate] 
    @Id int,
    @CreatedOn datetime2(7),
    @PatientId int,
    @ScheduleId int,
    @StartDate datetime2(7),
    @EndDate datetime2(7) = NULL
AS 

	UPDATE [dbo].[PatientDrugs]
	SET    [CreatedOn] = @CreatedOn, [PatientId] = @PatientId, [ScheduleId] = @ScheduleId, [StartDate] = @StartDate, [EndDate] = @EndDate
	WHERE  [Id] = @Id
	
GO

-- %% [markdown]
-- # [dbo].[PatientGetAll]

-- %%
/****** Object:  StoredProcedure [dbo].[PatientGetAll]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[PatientGetAll]
as 
begin 
select * from Patient
end
GO

-- %% [markdown]
-- # [dbo].[PatientInsert]

-- %%
/****** Object:  StoredProcedure [dbo].[PatientInsert]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[PatientInsert] 
    @CreatedOn datetime2(7),
    @UserId int,
    @Liters float,
    @SubscriptionValidation datetime2(7) = NULL
AS 

	INSERT INTO [dbo].[Patient] ([CreatedOn], [UserId], [Liters], [SubscriptionValidation])
	SELECT @CreatedOn, @UserId, @Liters, @SubscriptionValidation
	
GO

-- %% [markdown]
-- # [dbo].[PatientSelect]

-- %%
/****** Object:  StoredProcedure [dbo].[PatientSelect]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
----------------------------------------------------------------------------------------
----------------------------------------------------------------------------------------

CREATE PROC [dbo].[PatientSelect] 
    @Id int
AS 

	SELECT [Id], [CreatedOn], [UserId], [Liters], [SubscriptionValidation] 
	FROM   [dbo].[Patient] 
	WHERE  ([Id] = @Id OR @Id IS NULL) 

GO

-- %% [markdown]
-- # [dbo].[PatientUpdate]

-- %%
/****** Object:  StoredProcedure [dbo].[PatientUpdate]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[PatientUpdate] 
    @Id int,
    @CreatedOn datetime2(7),
    @UserId int,
    @Liters float,
    @SubscriptionValidation datetime2(7) = NULL
AS 

	UPDATE [dbo].[Patient]
	SET    [CreatedOn] = @CreatedOn, [UserId] = @UserId, [Liters] = @Liters, [SubscriptionValidation] = @SubscriptionValidation
	WHERE  [Id] = @Id
	
GO

-- %% [markdown]
-- # [dbo].[RolesDelete]

-- %%
/****** Object:  StoredProcedure [dbo].[RolesDelete]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[RolesDelete] 
    @Id int
AS 

	DELETE
	FROM   [dbo].[Roles]
	WHERE  [Id] = @Id

GO

-- %% [markdown]
-- # [dbo].[RolesInsert]

-- %%
/****** Object:  StoredProcedure [dbo].[RolesInsert]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[RolesInsert] 
    @CreatedOn datetime2(7),
    @Name nvarchar(50)
AS 

	INSERT INTO [dbo].[Roles] ([CreatedOn], [Name])
	SELECT @CreatedOn, @Name
	
GO

-- %% [markdown]
-- # [dbo].[RolesSelect]

-- %%
/****** Object:  StoredProcedure [dbo].[RolesSelect]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
----------------------------------------------------------------------------------------
----------------------------------------------------------------------------------------

CREATE PROC [dbo].[RolesSelect] 
    @Id int
AS 

	SELECT [Id], [CreatedOn], [Name] 
	FROM   [dbo].[Roles] 
	WHERE  ([Id] = @Id OR @Id IS NULL) 

GO

-- %% [markdown]
-- # [dbo].[RolesUpdate]

-- %%
/****** Object:  StoredProcedure [dbo].[RolesUpdate]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[RolesUpdate] 
    @Id int,
    @CreatedOn datetime2(7),
    @Name nvarchar(50)
AS 

	UPDATE [dbo].[Roles]
	SET    [CreatedOn] = @CreatedOn, [Name] = @Name
	WHERE  [Id] = @Id
	
GO

-- %% [markdown]
-- # [dbo].[ScheduleEnumDelete]

-- %%
/****** Object:  StoredProcedure [dbo].[ScheduleEnumDelete]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[ScheduleEnumDelete] 
    @Id int
AS 

	DELETE
	FROM   [dbo].[ScheduleEnum]
	WHERE  [Id] = @Id

GO

-- %% [markdown]
-- # [dbo].[ScheduleEnumGetAll]

-- %%
/****** Object:  StoredProcedure [dbo].[ScheduleEnumGetAll]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[ScheduleEnumGetAll]
as 
begin 
select * from ScheduleEnum
end
GO

-- %% [markdown]
-- # [dbo].[ScheduleEnumInsert]

-- %%
/****** Object:  StoredProcedure [dbo].[ScheduleEnumInsert]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[ScheduleEnumInsert] 
    @CreatedOn datetime2(7),
    @ValueName nvarchar(100)
AS 

	INSERT INTO [dbo].[ScheduleEnum] ([CreatedOn], [ValueName])
	SELECT @CreatedOn, @ValueName
	
GO

-- %% [markdown]
-- # [dbo].[ScheduleEnumSelect]

-- %%
/****** Object:  StoredProcedure [dbo].[ScheduleEnumSelect]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
----------------------------------------------------------------------------------------
----------------------------------------------------------------------------------------

CREATE PROC [dbo].[ScheduleEnumSelect] 
    @Id int
AS 

	SELECT [Id], [CreatedOn], [ValueName] 
	FROM   [dbo].[ScheduleEnum] 
	WHERE  ([Id] = @Id OR @Id IS NULL) 

GO

-- %% [markdown]
-- # [dbo].[ScheduleEnumUpdate]

-- %%
/****** Object:  StoredProcedure [dbo].[ScheduleEnumUpdate]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[ScheduleEnumUpdate] 
    @Id int,
    @CreatedOn datetime2(7),
    @ValueName nvarchar(100)
AS 

	UPDATE [dbo].[ScheduleEnum]
	SET    [CreatedOn] = @CreatedOn, [ValueName] = @ValueName
	WHERE  [Id] = @Id
	
GO

-- %% [markdown]
-- # [dbo].[StatusOrderEnumDelete]

-- %%
/****** Object:  StoredProcedure [dbo].[StatusOrderEnumDelete]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[StatusOrderEnumDelete] 
    @Id int
AS 

	DELETE
	FROM   [dbo].[StatusOrderEnum]
	WHERE  [Id] = @Id

GO

-- %% [markdown]
-- # [dbo].[StatusOrderEnumInsert]

-- %%
/****** Object:  StoredProcedure [dbo].[StatusOrderEnumInsert]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[StatusOrderEnumInsert] 
    @CreatedOn datetime2(7),
    @Status nvarchar(MAX)
AS 

	INSERT INTO [dbo].[StatusOrderEnum] ([CreatedOn], [Status])
	SELECT @CreatedOn, @Status
	
GO

-- %% [markdown]
-- # [dbo].[StatusOrderEnumSelect]

-- %%
/****** Object:  StoredProcedure [dbo].[StatusOrderEnumSelect]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
----------------------------------------------------------------------------------------
----------------------------------------------------------------------------------------

CREATE PROC [dbo].[StatusOrderEnumSelect] 
    @Id int
AS 

	SELECT [Id], [CreatedOn], [Status] 
	FROM   [dbo].[StatusOrderEnum] 
	WHERE  ([Id] = @Id OR @Id IS NULL) 

GO

-- %% [markdown]
-- # [dbo].[StatusOrderEnumUpdate]

-- %%
/****** Object:  StoredProcedure [dbo].[StatusOrderEnumUpdate]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[StatusOrderEnumUpdate] 
    @Id int,
    @CreatedOn datetime2(7),
    @Status nvarchar(MAX)
AS 

	UPDATE [dbo].[StatusOrderEnum]
	SET    [CreatedOn] = @CreatedOn, [Status] = @Status
	WHERE  [Id] = @Id
	
GO

-- %% [markdown]
-- # [dbo].[SubscribeTypeDelete]

-- %%
/****** Object:  StoredProcedure [dbo].[SubscribeTypeDelete]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[SubscribeTypeDelete] 
    @Id int
AS 

	DELETE
	FROM   [dbo].[SubscribeType]
	WHERE  [Id] = @Id

GO

-- %% [markdown]
-- # [dbo].[SubscribeTypeInsert]

-- %%
/****** Object:  StoredProcedure [dbo].[SubscribeTypeInsert]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[SubscribeTypeInsert] 
    @CreatedOn datetime2(7),
    @Type nvarchar(150),
    @SubscribePrice float,
    @SubscribeDescription nvarchar(1000),
    @Days int
AS 

	INSERT INTO [dbo].[SubscribeType] ([CreatedOn], [Type], [SubscribePrice], [SubscribeDescription], [Days])
	SELECT @CreatedOn, @Type, @SubscribePrice, @SubscribeDescription, @Days
	
GO

-- %% [markdown]
-- # [dbo].[SubscribeTypeSelect]

-- %%
/****** Object:  StoredProcedure [dbo].[SubscribeTypeSelect]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
----------------------------------------------------------------------------------------
----------------------------------------------------------------------------------------

CREATE PROC [dbo].[SubscribeTypeSelect] 
    @Id int
AS 

	SELECT [Id], [CreatedOn], [Type], [SubscribePrice], [SubscribeDescription], [Days] 
	FROM   [dbo].[SubscribeType] 
	WHERE  ([Id] = @Id OR @Id IS NULL) 

GO

-- %% [markdown]
-- # [dbo].[SubscribeTypeUpdate]

-- %%
/****** Object:  StoredProcedure [dbo].[SubscribeTypeUpdate]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[SubscribeTypeUpdate] 
    @Id int,
    @CreatedOn datetime2(7),
    @Type nvarchar(150),
    @SubscribePrice float,
    @SubscribeDescription nvarchar(1000),
    @Days int
AS 

	UPDATE [dbo].[SubscribeType]
	SET    [CreatedOn] = @CreatedOn, [Type] = @Type, [SubscribePrice] = @SubscribePrice, [SubscribeDescription] = @SubscribeDescription, [Days] = @Days
	WHERE  [Id] = @Id
	
GO

-- %% [markdown]
-- # [dbo].[SubscriptionDelete]

-- %%
/****** Object:  StoredProcedure [dbo].[SubscriptionDelete]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[SubscriptionDelete] 
    @Id int
AS 

	DELETE
	FROM   [dbo].[Subscription]
	WHERE  [Id] = @Id

GO

-- %% [markdown]
-- # [dbo].[SubscriptionInsert]

-- %%
/****** Object:  StoredProcedure [dbo].[SubscriptionInsert]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[SubscriptionInsert] 
    @CreatedOn datetime2(7),
    @PatientId int,
    @SubscribeTypeId int
AS 

	INSERT INTO [dbo].[Subscription] ([CreatedOn], [PatientId], [SubscribeTypeId])
	SELECT @CreatedOn, @PatientId, @SubscribeTypeId
	
GO

-- %% [markdown]
-- # [dbo].[SubscriptionSelect]

-- %%
/****** Object:  StoredProcedure [dbo].[SubscriptionSelect]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
----------------------------------------------------------------------------------------
----------------------------------------------------------------------------------------

CREATE PROC [dbo].[SubscriptionSelect] 
    @Id int
AS 

	SELECT [Id], [CreatedOn], [PatientId], [SubscribeTypeId] 
	FROM   [dbo].[Subscription] 
	WHERE  ([Id] = @Id OR @Id IS NULL) 

GO

-- %% [markdown]
-- # [dbo].[SubscriptionTypeGetAll]

-- %%
/****** Object:  StoredProcedure [dbo].[SubscriptionTypeGetAll]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[SubscriptionTypeGetAll]
as 
begin 
select * from SubscriptionType
end
GO

-- %% [markdown]
-- # [dbo].[SubscriptionUpdate]

-- %%
/****** Object:  StoredProcedure [dbo].[SubscriptionUpdate]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[SubscriptionUpdate] 
    @Id int,
    @CreatedOn datetime2(7),
    @PatientId int,
    @SubscribeTypeId int
AS 

	UPDATE [dbo].[Subscription]
	SET    [CreatedOn] = @CreatedOn, [PatientId] = @PatientId, [SubscribeTypeId] = @SubscribeTypeId
	WHERE  [Id] = @Id
	
GO

-- %% [markdown]
-- # [dbo].[UserDelete]

-- %%
/****** Object:  StoredProcedure [dbo].[UserDelete]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[UserDelete] 
    @Id int
AS 

	DELETE
	FROM   [dbo].[User]
	WHERE  [Id] = @Id

GO

-- %% [markdown]
-- # [dbo].[UserInsert]

-- %%
/****** Object:  StoredProcedure [dbo].[UserInsert]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[UserInsert] 
    @CreatedOn datetime2(7),
    @Email nvarchar(150),
    @PasswordHash nvarchar(100),
    @PhoneNumber nvarchar(15),
    @FirstName nvarchar(50),
    @LastName nvarchar(50),
    @ProfilePicturePath nvarchar(250) = NULL,
    @LocationId int = NULL,
    @EmployeeId int = NULL,
    @PatientId int = NULL
AS 

	INSERT INTO [dbo].[User] ([CreatedOn], [Email], [PasswordHash], [PhoneNumber], [FirstName], [LastName], [ProfilePicturePath], [LocationId], [EmployeeId], [PatientId])
	SELECT @CreatedOn, @Email, @PasswordHash, @PhoneNumber, @FirstName, @LastName, @ProfilePicturePath, @LocationId, @EmployeeId, @PatientId
	SELECT SCOPE_IDENTITY()

GO

-- %% [markdown]
-- # [dbo].[UserLoginsDelete]

-- %%
/****** Object:  StoredProcedure [dbo].[UserLoginsDelete]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[UserLoginsDelete] 
    @Id int
AS 

	DELETE
	FROM   [dbo].[UserLogins]
	WHERE  [Id] = @Id

GO

-- %% [markdown]
-- # [dbo].[UserLoginsGetAll]

-- %%
/****** Object:  StoredProcedure [dbo].[UserLoginsGetAll]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[UserLoginsGetAll]
as 
begin 
select * from UserLogins
end
GO

-- %% [markdown]
-- # [dbo].[UserLoginsInsert]

-- %%
/****** Object:  StoredProcedure [dbo].[UserLoginsInsert]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[UserLoginsInsert] 
    @CreatedOn datetime2(7),
    @LoginProvider nvarchar(MAX) = NULL,
    @ProviderKey nvarchar(MAX) = NULL,
    @ProviderDisplayName nvarchar(MAX) = NULL,
    @UserId int
AS 

	INSERT INTO [dbo].[UserLogins] ([CreatedOn], [LoginProvider], [ProviderKey], [ProviderDisplayName], [UserId])
	SELECT @CreatedOn, @LoginProvider, @ProviderKey, @ProviderDisplayName, @UserId
	
GO

-- %% [markdown]
-- # [dbo].[UserLoginsSelect]

-- %%
/****** Object:  StoredProcedure [dbo].[UserLoginsSelect]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
----------------------------------------------------------------------------------------
----------------------------------------------------------------------------------------

CREATE PROC [dbo].[UserLoginsSelect] 
    @Id int
AS 

	SELECT [Id], [CreatedOn], [LoginProvider], [ProviderKey], [ProviderDisplayName], [UserId] 
	FROM   [dbo].[UserLogins] 
	WHERE  ([Id] = @Id OR @Id IS NULL) 

GO

-- %% [markdown]
-- # [dbo].[UserLoginsUpdate]

-- %%
/****** Object:  StoredProcedure [dbo].[UserLoginsUpdate]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[UserLoginsUpdate] 
    @Id int,
    @CreatedOn datetime2(7),
    @LoginProvider nvarchar(MAX) = NULL,
    @ProviderKey nvarchar(MAX) = NULL,
    @ProviderDisplayName nvarchar(MAX) = NULL,
    @UserId int
AS 

	UPDATE [dbo].[UserLogins]
	SET    [CreatedOn] = @CreatedOn, [LoginProvider] = @LoginProvider, [ProviderKey] = @ProviderKey, [ProviderDisplayName] = @ProviderDisplayName, [UserId] = @UserId
	WHERE  [Id] = @Id
	
GO

-- %% [markdown]
-- # [dbo].[UserRoleGetAll]

-- %%
/****** Object:  StoredProcedure [dbo].[UserRoleGetAll]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[UserRoleGetAll]
as 
begin 
select * from UserRole
end
GO

-- %% [markdown]
-- # [dbo].[UserRolesDelete]

-- %%
/****** Object:  StoredProcedure [dbo].[UserRolesDelete]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[UserRolesDelete] 
    @Id int
AS 

	DELETE
	FROM   [dbo].[UserRoles]
	WHERE  [Id] = @Id

GO

-- %% [markdown]
-- # [dbo].[UserRolesInsert]

-- %%
/****** Object:  StoredProcedure [dbo].[UserRolesInsert]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[UserRolesInsert] 
    @CreatedOn datetime2(7),
    @UserId int,
    @RoleId int
AS 

	INSERT INTO [dbo].[UserRoles] ([CreatedOn], [UserId], [RoleId])
	SELECT @CreatedOn, @UserId, @RoleId
	
GO

-- %% [markdown]
-- # [dbo].[UserRolesSelect]

-- %%
/****** Object:  StoredProcedure [dbo].[UserRolesSelect]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
----------------------------------------------------------------------------------------
----------------------------------------------------------------------------------------

CREATE PROC [dbo].[UserRolesSelect] 
    @Id int
AS 

	SELECT [Id], [CreatedOn], [UserId], [RoleId] 
	FROM   [dbo].[UserRoles] 
	WHERE  ([Id] = @Id OR @Id IS NULL) 

GO

-- %% [markdown]
-- # [dbo].[UserRolesUpdate]

-- %%
/****** Object:  StoredProcedure [dbo].[UserRolesUpdate]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[UserRolesUpdate] 
    @Id int,
    @CreatedOn datetime2(7),
    @UserId int,
    @RoleId int
AS 

	UPDATE [dbo].[UserRoles]
	SET    [CreatedOn] = @CreatedOn, [UserId] = @UserId, [RoleId] = @RoleId
	WHERE  [Id] = @Id
	
GO

-- %% [markdown]
-- # [dbo].[UserSelect]

-- %%
/****** Object:  StoredProcedure [dbo].[UserSelect]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
----------------------------------------------------------------------------------------
----------------------------------------------------------------------------------------

CREATE PROC [dbo].[UserSelect] 
    @Id int
AS 

	SELECT [Id], [CreatedOn], [Email], [PasswordHash], [PhoneNumber], [FirstName], [LastName], [ProfilePicturePath], [LocationId], [EmployeeId], [PatientId] 
	FROM   [dbo].[User] 
	WHERE  ([Id] = @Id OR @Id IS NULL) 

GO

-- %% [markdown]
-- # [dbo].[UsersGetAll]

-- %%
/****** Object:  StoredProcedure [dbo].[UsersGetAll]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[UsersGetAll]
as 
begin 
select * from [User]
end
GO

-- %% [markdown]
-- # [dbo].[UserTokensDelete]

-- %%
/****** Object:  StoredProcedure [dbo].[UserTokensDelete]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[UserTokensDelete] 
    @Id int
AS 

	DELETE
	FROM   [dbo].[UserTokens]
	WHERE  [Id] = @Id

GO

-- %% [markdown]
-- # [dbo].[UserTokensInsert]

-- %%
/****** Object:  StoredProcedure [dbo].[UserTokensInsert]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[UserTokensInsert] 
    @CreatedOn datetime2(7),
    @UserId int,
    @LoginProvider nvarchar(MAX) = NULL,
    @Name nvarchar(MAX) = NULL,
    @Value nvarchar(MAX) = NULL
AS 

	INSERT INTO [dbo].[UserTokens] ([CreatedOn], [UserId], [LoginProvider], [Name], [Value])
	SELECT @CreatedOn, @UserId, @LoginProvider, @Name, @Value
	
GO

-- %% [markdown]
-- # [dbo].[UserTokensSelect]

-- %%
/****** Object:  StoredProcedure [dbo].[UserTokensSelect]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
----------------------------------------------------------------------------------------
----------------------------------------------------------------------------------------

CREATE PROC [dbo].[UserTokensSelect] 
    @Id int
AS 

	SELECT [Id], [CreatedOn], [UserId], [LoginProvider], [Name], [Value] 
	FROM   [dbo].[UserTokens] 
	WHERE  ([Id] = @Id OR @Id IS NULL) 

GO

-- %% [markdown]
-- # [dbo].[UserTokensUpdate]

-- %%
/****** Object:  StoredProcedure [dbo].[UserTokensUpdate]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[UserTokensUpdate] 
    @Id int,
    @CreatedOn datetime2(7),
    @UserId int,
    @LoginProvider nvarchar(MAX) = NULL,
    @Name nvarchar(MAX) = NULL,
    @Value nvarchar(MAX) = NULL
AS 

	UPDATE [dbo].[UserTokens]
	SET    [CreatedOn] = @CreatedOn, [UserId] = @UserId, [LoginProvider] = @LoginProvider, [Name] = @Name, [Value] = @Value
	WHERE  [Id] = @Id
	
GO

-- %% [markdown]
-- # [dbo].[UserUpdate]

-- %%
/****** Object:  StoredProcedure [dbo].[UserUpdate]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[UserUpdate] 
    @Id int,
    @CreatedOn datetime2(7),
    @Email nvarchar(150),
    @PasswordHash nvarchar(100),
    @PhoneNumber nvarchar(15),
    @FirstName nvarchar(50),
    @LastName nvarchar(50),
    @ProfilePicturePath nvarchar(250) = NULL,
    @LocationId int = NULL,
    @EmployeeId int = NULL,
    @PatientId int = NULL
AS 

	UPDATE [dbo].[User]
	SET    [CreatedOn] = @CreatedOn, [Email] = @Email, [PasswordHash] = @PasswordHash, [PhoneNumber] = @PhoneNumber, [FirstName] = @FirstName, [LastName] = @LastName, [ProfilePicturePath] = @ProfilePicturePath, [LocationId] = @LocationId, [EmployeeId] = @EmployeeId, [PatientId] = @PatientId
	WHERE  [Id] = @Id
	
GO

-- %% [markdown]
-- # [dbo].[WorkDelete]

-- %%
/****** Object:  StoredProcedure [dbo].[WorkDelete]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[WorkDelete] 
    @Id int
AS 

	DELETE
	FROM   [dbo].[Work]
	WHERE  [Id] = @Id

GO

-- %% [markdown]
-- # [dbo].[WorkInsert]

-- %%
/****** Object:  StoredProcedure [dbo].[WorkInsert]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[WorkInsert] 
    @CreatedOn datetime2(7),
    @StartDate datetime2(7),
    @EndDate datetime2(7) = NULL,
    @EmployeeId int
AS 

	INSERT INTO [dbo].[Work] ([CreatedOn], [StartDate], [EndDate], [EmployeeId])
	SELECT @CreatedOn, @StartDate, @EndDate, @EmployeeId
	
GO

-- %% [markdown]
-- # [dbo].[WorkSelect]

-- %%
/****** Object:  StoredProcedure [dbo].[WorkSelect]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
----------------------------------------------------------------------------------------
----------------------------------------------------------------------------------------

CREATE PROC [dbo].[WorkSelect] 
    @Id int
AS 

	SELECT [Id], [CreatedOn], [StartDate], [EndDate], [EmployeeId] 
	FROM   [dbo].[Work] 
	WHERE  ([Id] = @Id OR @Id IS NULL) 

GO

-- %% [markdown]
-- # [dbo].[WorkUpdate]

-- %%
/****** Object:  StoredProcedure [dbo].[WorkUpdate]    Script Date: 11/13/2021 12:12:22 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[WorkUpdate] 
    @Id int,
    @CreatedOn datetime2(7),
    @StartDate datetime2(7),
    @EndDate datetime2(7) = NULL,
    @EmployeeId int
AS 

	UPDATE [dbo].[Work]
	SET    [CreatedOn] = @CreatedOn, [StartDate] = @StartDate, [EndDate] = @EndDate, [EmployeeId] = @EmployeeId
	WHERE  [Id] = @Id
	
GO
